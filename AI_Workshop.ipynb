# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaishnavi639/AI-session/blob/main/AI_Workshop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/insanesac/ai_workshop.git
# Out:
# Cloning into 'ai_workshop'...
# remote: Enumerating objects: 49, done.
# remote: Counting objects: 100% (49/49), done.
# remote: Compressing objects: 100% (46/46), done.
# remote: Total 49 (delta 0), reused 49 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (49/49), 1.97 MiB | 4.34 MiB/s, done.

# %%
cd ai_workshop/
# Out:
# /content/ai_workshop

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
# !pip install -r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt
# Out:
# Collecting numpy==1.26.4 (from -r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 5))
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 3.8 MB/s eta 0:00:00
# Collecting pandas==2.2.0 (from -r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 6))
#   Downloading pandas-2.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: torch==2.6.0 in /usr/local/lib/python3.11/dist-packages (from -r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 9)) (2.6.0+cu124)
# Requirement already satisfied: torchvision==0.21.0 in /usr/local/lib/python3.11/dist-packages (from -r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 10)) (0.21.0+cu124)
# Requirement already satisfied: torchaudio==2.6.0 in /usr/local/lib/python3.11/dist-packages (from -r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 11)) (2.6.0+cu124)
# Requirement already satisfied: tensorflow==2.18.0 in /usr/local/lib/python3.11/dist-packages (from -r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 12)) (2.18.0)
# Collecting transformers==4.46.0 (from -r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 15))
#   Downloading transformers-4.46.0-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.1/44.1 kB 4.0 MB/s eta 0:00:00
# Collecting sentence-transformers==3.3.0 (from -r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 16))
#   Downloading sentence_transformers-3.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting datasets==3.1.0 (from -r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 17))
#   Downloading datasets-3.1.0-py3-none-any.whl.metadata (20 kB)
# Collecting accelerate==1.1.0 (from -r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 18))
#   Downloading accelerate-1.1.0-py3-none-any.whl.metadata (19 kB)
# Collecting tokenizers==0.20.1 (from -r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 19))
#   Downloading tokenizers-0.20.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting opencv-python==4.10.0.84 (from -r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 22))
#   Downloading opencv_python-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting pillow==10.4.0 (from -r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 23))
#   Downloading pillow-10.4.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# Collecting ultralytics==8.3.0 (from -r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 24))
#   Downloading ultralytics-8.3.0-py3-none-any.whl.metadata (34 kB)
# Collecting matplotlib==3.9.2 (from -r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 27))
#   Downloading matplotlib-3.9.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: seaborn==0.13.2 in /usr/local/lib/python3.11/dist-packages (from -r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 28)) (0.13.2)
# Collecting scikit-learn==1.5.2 (from -r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 31))
#   Downloading scikit_learn-1.5.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Collecting faiss-cpu==1.8.0 (from -r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 32))
#   Downloading faiss_cpu-1.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Requirement already satisfied: requests==2.32.3 in /usr/local/lib/python3.11/dist-packages (from -r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 35)) (2.32.3)
# Collecting beautifulsoup4==4.12.3 (from -r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 36))
#   Downloading beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting gradio==5.5.0 (from -r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 37))
#   Downloading gradio-5.5.0-py3-none-any.whl.metadata (16 kB)
# Collecting jupyter==1.1.1 (from -r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 40))
#   Downloading jupyter-1.1.1-py2.py3-none-any.whl.metadata (2.0 kB)
# Collecting ipywidgets==8.1.5 (from -r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 41))
#   Downloading ipywidgets-8.1.5-py3-none-any.whl.metadata (2.3 kB)
# Collecting notebook==7.2.2 (from -r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42))
#   Downloading notebook-7.2.2-py3-none-any.whl.metadata (10 kB)
# Collecting tqdm==4.66.6 (from -r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 45))
#   Downloading tqdm-4.66.6-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 5.5 MB/s eta 0:00:00
# Collecting psutil==6.1.0 (from -r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 46))
#   Downloading psutil-6.1.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting pytest==8.3.3 (from -r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 49))
#   Downloading pytest-8.3.3-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas==2.2.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 6)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas==2.2.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 6)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas==2.2.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 6)) (2025.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 9)) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 9)) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 9)) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 9)) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 9)) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch==2.6.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 9))
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch==2.6.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 9))
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch==2.6.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 9))
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch==2.6.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 9))
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch==2.6.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 9))
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch==2.6.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 9))
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch==2.6.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 9))
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch==2.6.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 9))
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch==2.6.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 9))
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 9)) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 9)) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 9)) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch==2.6.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 9))
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 9)) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 9)) (1.13.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 12)) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 12)) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 12)) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 12)) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 12)) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 12)) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 12)) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 12)) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 12)) (5.29.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 12)) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 12)) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 12)) (3.1.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 12)) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 12)) (1.73.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 12)) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 12)) (3.8.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 12)) (3.14.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 12)) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 12)) (0.37.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.11/dist-packages (from transformers==4.46.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 15)) (0.33.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.46.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 15)) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.46.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 15)) (2024.11.6)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.46.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 15)) (0.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from sentence-transformers==3.3.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 16)) (1.15.3)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets==3.1.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 17)) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets==3.1.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 17)) (0.3.7)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets==3.1.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 17)) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets==3.1.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 17)) (0.70.15)
# Collecting fsspec (from torch==2.6.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 9))
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets==3.1.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 17)) (3.11.15)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics==8.3.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 24)) (9.0.0)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics==8.3.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 24))
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.9.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 27)) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.9.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 27)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.9.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 27)) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.9.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 27)) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.9.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 27)) (3.2.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.5.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 31)) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.5.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 31)) (3.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests==2.32.3->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 35)) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests==2.32.3->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 35)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests==2.32.3->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 35)) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests==2.32.3->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 35)) (2025.7.14)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4==4.12.3->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 36)) (2.7)
# Collecting aiofiles<24.0,>=22.0 (from gradio==5.5.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 37))
#   Downloading aiofiles-23.2.1-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.11/dist-packages (from gradio==5.5.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 37)) (4.9.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /usr/local/lib/python3.11/dist-packages (from gradio==5.5.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 37)) (0.116.1)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.11/dist-packages (from gradio==5.5.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 37)) (0.6.0)
# Collecting gradio-client==1.4.2 (from gradio==5.5.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 37))
#   Downloading gradio_client-1.4.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: httpx>=0.24.1 in /usr/local/lib/python3.11/dist-packages (from gradio==5.5.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 37)) (0.28.1)
# Collecting markupsafe~=2.0 (from gradio==5.5.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 37))
#   Downloading MarkupSafe-2.1.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.11/dist-packages (from gradio==5.5.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 37)) (3.11.0)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.11/dist-packages (from gradio==5.5.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 37)) (2.11.7)
# Requirement already satisfied: pydub in /usr/local/lib/python3.11/dist-packages (from gradio==5.5.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 37)) (0.25.1)
# Collecting python-multipart==0.0.12 (from gradio==5.5.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 37))
#   Downloading python_multipart-0.0.12-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: ruff>=0.2.2 in /usr/local/lib/python3.11/dist-packages (from gradio==5.5.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 37)) (0.12.3)
# Requirement already satisfied: safehttpx<1.0,>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from gradio==5.5.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 37)) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.11/dist-packages (from gradio==5.5.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 37)) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /usr/local/lib/python3.11/dist-packages (from gradio==5.5.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 37)) (0.47.1)
# Collecting tomlkit==0.12.0 (from gradio==5.5.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 37))
#   Downloading tomlkit-0.12.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.11/dist-packages (from gradio==5.5.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 37)) (0.16.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.11/dist-packages (from gradio==5.5.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 37)) (0.35.0)
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.11/dist-packages (from jupyter==1.1.1->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 40)) (6.1.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.11/dist-packages (from jupyter==1.1.1->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 40)) (7.16.6)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.11/dist-packages (from jupyter==1.1.1->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 40)) (6.17.1)
# Collecting jupyterlab (from jupyter==1.1.1->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 40))
#   Downloading jupyterlab-4.4.4-py3-none-any.whl.metadata (16 kB)
# Collecting comm>=0.1.3 (from ipywidgets==8.1.5->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 41))
#   Downloading comm-0.2.2-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: ipython>=6.1.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets==8.1.5->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 41)) (7.34.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.11/dist-packages (from ipywidgets==8.1.5->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 41)) (5.7.1)
# Collecting widgetsnbextension~=4.0.12 (from ipywidgets==8.1.5->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 41))
#   Downloading widgetsnbextension-4.0.14-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /usr/local/lib/python3.11/dist-packages (from ipywidgets==8.1.5->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 41)) (3.0.15)
# Collecting jupyter-server<3,>=2.4.0 (from notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42))
#   Downloading jupyter_server-2.16.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting jupyterlab-server<3,>=2.27.1 (from notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42))
#   Downloading jupyterlab_server-2.27.3-py3-none-any.whl.metadata (5.9 kB)
# Collecting jupyterlab (from jupyter==1.1.1->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 40))
#   Downloading jupyterlab-4.2.7-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /usr/local/lib/python3.11/dist-packages (from notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (6.4.2)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.11/dist-packages (from pytest==8.3.3->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 49)) (2.1.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.11/dist-packages (from pytest==8.3.3->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 49)) (1.6.0)
# Collecting websockets<13.0,>=10.0 (from gradio-client==1.4.2->gradio==5.5.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 37))
#   Downloading websockets-12.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch==2.6.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 9)) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<5.0,>=3.0->gradio==5.5.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 37)) (1.3.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow==2.18.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 12)) (0.45.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets==3.1.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 17)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets==3.1.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 17)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets==3.1.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 17)) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets==3.1.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 17)) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets==3.1.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 17)) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets==3.1.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 17)) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets==3.1.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 17)) (1.20.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.24.1->gradio==5.5.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 37)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.24.1->gradio==5.5.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 37)) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.46.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 15)) (1.1.5)
# Collecting jedi>=0.16 (from ipython>=6.1.0->ipywidgets==8.1.5->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 41))
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=6.1.0->ipywidgets==8.1.5->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 41)) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=6.1.0->ipywidgets==8.1.5->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 41)) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=6.1.0->ipywidgets==8.1.5->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 41)) (3.0.51)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython>=6.1.0->ipywidgets==8.1.5->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 41)) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=6.1.0->ipywidgets==8.1.5->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 41)) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from ipython>=6.1.0->ipywidgets==8.1.5->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 41)) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=6.1.0->ipywidgets==8.1.5->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 41)) (4.9.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=2.4.0->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (25.1.0)
# Collecting jupyter-client>=7.4.4 (from jupyter-server<3,>=2.4.0->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42))
#   Downloading jupyter_client-8.6.3-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=2.4.0->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (5.8.1)
# Collecting jupyter-events>=0.11.0 (from jupyter-server<3,>=2.4.0->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42))
#   Downloading jupyter_events-0.12.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting jupyter-server-terminals>=0.4.4 (from jupyter-server<3,>=2.4.0->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42))
#   Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: nbformat>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=2.4.0->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (5.10.4)
# Collecting overrides>=5.0 (from jupyter-server<3,>=2.4.0->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42))
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: prometheus-client>=0.9 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=2.4.0->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (0.22.1)
# Requirement already satisfied: pyzmq>=24 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=2.4.0->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (24.0.1)
# Requirement already satisfied: send2trash>=1.8.2 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=2.4.0->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=2.4.0->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=2.4.0->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (1.8.0)
# Collecting async-lru>=1.0.0 (from jupyterlab->jupyter==1.1.1->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 40))
#   Downloading async_lru-2.0.5-py3-none-any.whl.metadata (4.5 kB)
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab->jupyter==1.1.1->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 40))
#   Downloading jupyter_lsp-2.2.6-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel->jupyter==1.1.1->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 40)) (1.8.0)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from ipykernel->jupyter==1.1.1->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 40)) (1.6.0)
# Requirement already satisfied: babel>=2.10 in /usr/local/lib/python3.11/dist-packages (from jupyterlab-server<3,>=2.27.1->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (2.17.0)
# Collecting json5>=0.9.0 (from jupyterlab-server<3,>=2.27.1->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42))
#   Downloading json5-0.12.0-py3-none-any.whl.metadata (36 kB)
# Requirement already satisfied: jsonschema>=4.18.0 in /usr/local/lib/python3.11/dist-packages (from jupyterlab-server<3,>=2.27.1->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (4.24.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow==2.18.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 12)) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow==2.18.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 12)) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow==2.18.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 12)) (0.16.0)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert->jupyter==1.1.1->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 40)) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/dist-packages (from nbconvert->jupyter==1.1.1->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 40)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.11/dist-packages (from nbconvert->jupyter==1.1.1->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 40)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from nbconvert->jupyter==1.1.1->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 40)) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert->jupyter==1.1.1->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 40)) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from nbconvert->jupyter==1.1.1->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 40)) (1.5.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.0->gradio==5.5.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 37)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.0->gradio==5.5.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 37)) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.0->gradio==5.5.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 37)) (0.4.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow==2.18.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 12)) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow==2.18.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 12)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow==2.18.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 12)) (3.1.3)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0,>=0.12->gradio==5.5.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 37)) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0,>=0.12->gradio==5.5.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 37)) (1.5.4)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.11/dist-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (21.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter==1.1.1->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 40)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert->jupyter==1.1.1->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 40)) (1.4.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets==8.1.5->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 41)) (0.8.4)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (0.26.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (4.3.8)
# Collecting python-json-logger>=2.0.4 (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42))
#   Downloading python_json_logger-3.3.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting rfc3339-validator (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42))
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting rfc3986-validator>=0.1.1 (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42))
#   Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.11/dist-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (2.21.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets==8.1.5->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 41)) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=6.1.0->ipywidgets==8.1.5->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 41)) (0.2.13)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow==2.18.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 12)) (3.0.0)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42))
#   Downloading fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42))
#   Downloading isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.11/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (3.0.0)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42))
#   Downloading uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (24.11.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow==2.18.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 12)) (0.1.2)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (2.22)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.0/27.0 MB 81.5 MB/s eta 0:00:00
# Downloading beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.9/147.9 kB 14.2 MB/s eta 0:00:00
# Downloading gradio-5.5.0-py3-none-any.whl (56.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.7/56.7 MB 11.0 MB/s eta 0:00:00
# Downloading jupyter-1.1.1-py2.py3-none-any.whl (2.7 kB)
# Downloading ipywidgets-8.1.5-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 13.7 MB/s eta 0:00:00
# Downloading notebook-7.2.2-py3-none-any.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 97.5 MB/s eta 0:00:00
# Downloading tqdm-4.66.6-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 7.8 MB/s eta 0:00:00
# Downloading psutil-6.1.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (287 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.3/287.3 kB 27.6 MB/s eta 0:00:00
# Downloading pytest-8.3.3-py3-none-any.whl (342 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 342.3/342.3 kB 28.4 MB/s eta 0:00:00
# Downloading gradio_client-1.4.2-py3-none-any.whl (319 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.8/319.8 kB 27.7 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 114.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 82.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 46.2 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.9 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 43.3 MB/s eta 0:00:00
# Downloading python_multipart-0.0.12-py3-none-any.whl (23 kB)
# Downloading tomlkit-0.12.0-py3-none-any.whl (37 kB)
# Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Downloading comm-0.2.2-py3-none-any.whl (7.2 kB)
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 17.5 MB/s eta 0:00:00
# Downloading jupyter_server-2.16.0-py3-none-any.whl (386 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.9/386.9 kB 32.6 MB/s eta 0:00:00
# Downloading jupyterlab-4.2.7-py3-none-any.whl (11.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 122.2 MB/s eta 0:00:00
# Downloading jupyterlab_server-2.27.3-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 kB 5.4 MB/s eta 0:00:00
# Downloading MarkupSafe-2.1.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (28 kB)
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Downloading widgetsnbextension-4.0.14-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 89.5 MB/s eta 0:00:00
# Downloading async_lru-2.0.5-py3-none-any.whl (6.1 kB)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 73.5 MB/s eta 0:00:00
# Downloading json5-0.12.0-py3-none-any.whl (36 kB)
# Downloading jupyter_client-8.6.3-py3-none-any.whl (106 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.1/106.1 kB 10.4 MB/s eta 0:00:00
# Downloading jupyter_events-0.12.0-py3-none-any.whl (19 kB)
# Downloading jupyter_lsp-2.2.6-py3-none-any.whl (69 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 6.7 MB/s eta 0:00:00
# Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl (13 kB)
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading websockets-12.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.9/130.9 kB 12.9 MB/s eta 0:00:00
# Downloading python_json_logger-3.3.0-py3-none-any.whl (15 kB)
# Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Downloading arrow-1.3.0-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 6.9 MB/s eta 0:00:00
# Downloading types_python_dateutil-2.9.0.20250708-py3-none-any.whl (17 kB)
# Installing collected packages: widgetsnbextension, websockets, uri-template, types-python-dateutil, tqdm, tomlkit, rfc3986-validator, rfc3339-validator, python-multipart, python-json-logger, pytest, psutil, pillow, overrides, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, markupsafe, json5, jedi, fsspec, fqdn, comm, beautifulsoup4, async-lru, aiofiles, pandas, opencv-python, nvidia-cusparse-cu12, nvidia-cudnn-cu12, jupyter-server-terminals, jupyter-client, faiss-cpu, arrow, tokenizers, scikit-learn, nvidia-cusolver-cu12, matplotlib, isoduration, ipywidgets, gradio-client, transformers, gradio, datasets, ultralytics-thop, sentence-transformers, jupyter-events, accelerate, ultralytics, jupyter-server, jupyterlab-server, jupyter-lsp, jupyterlab, notebook, jupyter
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.6.10
#     Uninstalling widgetsnbextension-3.6.10:
#       Successfully uninstalled widgetsnbextension-3.6.10
#   Attempting uninstall: websockets
#     Found existing installation: websockets 15.0.1
#     Uninstalling websockets-15.0.1:
#       Successfully uninstalled websockets-15.0.1
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.67.1
#     Uninstalling tqdm-4.67.1:
#       Successfully uninstalled tqdm-4.67.1
#   Attempting uninstall: tomlkit
#     Found existing installation: tomlkit 0.13.3
#     Uninstalling tomlkit-0.13.3:
#       Successfully uninstalled tomlkit-0.13.3
#   Attempting uninstall: python-multipart
#     Found existing installation: python-multipart 0.0.20
#     Uninstalling python-multipart-0.0.20:
#       Successfully uninstalled python-multipart-0.0.20
#   Attempting uninstall: pytest
#     Found existing installation: pytest 8.3.5
#     Uninstalling pytest-8.3.5:
#       Successfully uninstalled pytest-8.3.5
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.9.5
#     Uninstalling psutil-5.9.5:
#       Successfully uninstalled psutil-5.9.5
#   Attempting uninstall: pillow
#     Found existing installation: pillow 11.2.1
#     Uninstalling pillow-11.2.1:
#       Successfully uninstalled pillow-11.2.1
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 3.0.2
#     Uninstalling MarkupSafe-3.0.2:
#       Successfully uninstalled MarkupSafe-3.0.2
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.13.4
#     Uninstalling beautifulsoup4-4.13.4:
#       Successfully uninstalled beautifulsoup4-4.13.4
#   Attempting uninstall: aiofiles
#     Found existing installation: aiofiles 24.1.0
#     Uninstalling aiofiles-24.1.0:
#       Successfully uninstalled aiofiles-24.1.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.11.0.86
#     Uninstalling opencv-python-4.11.0.86:
#       Successfully uninstalled opencv-python-4.11.0.86
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter-client 6.1.12
#     Uninstalling jupyter-client-6.1.12:
#       Successfully uninstalled jupyter-client-6.1.12
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.21.2
#     Uninstalling tokenizers-0.21.2:
#       Successfully uninstalled tokenizers-0.21.2
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.1
#     Uninstalling scikit-learn-1.6.1:
#       Successfully uninstalled scikit-learn-1.6.1
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.10.0
#     Uninstalling matplotlib-3.10.0:
#       Successfully uninstalled matplotlib-3.10.0
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.7.1
#     Uninstalling ipywidgets-7.7.1:
#       Successfully uninstalled ipywidgets-7.7.1
#   Attempting uninstall: gradio-client
#     Found existing installation: gradio_client 1.10.1
#     Uninstalling gradio_client-1.10.1:
#       Successfully uninstalled gradio_client-1.10.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.53.2
#     Uninstalling transformers-4.53.2:
#       Successfully uninstalled transformers-4.53.2
#   Attempting uninstall: gradio
#     Found existing installation: gradio 5.31.0
#     Uninstalling gradio-5.31.0:
#       Successfully uninstalled gradio-5.31.0
#   Attempting uninstall: datasets
#     Found existing installation: datasets 2.14.4
#     Uninstalling datasets-2.14.4:
#       Successfully uninstalled datasets-2.14.4
#   Attempting uninstall: sentence-transformers
#     Found existing installation: sentence-transformers 4.1.0
#     Uninstalling sentence-transformers-4.1.0:
#       Successfully uninstalled sentence-transformers-4.1.0
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 1.8.1
#     Uninstalling accelerate-1.8.1:
#       Successfully uninstalled accelerate-1.8.1
#   Attempting uninstall: jupyter-server
#     Found existing installation: jupyter-server 1.16.0
#     Uninstalling jupyter-server-1.16.0:
#       Successfully uninstalled jupyter-server-1.16.0
#   Attempting uninstall: notebook
#     Found existing installation: notebook 6.5.7
#     Uninstalling notebook-6.5.7:
#       Successfully uninstalled notebook-6.5.7
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires notebook==6.5.7, but you have notebook 7.2.2 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.0 which is incompatible.
# jupyter-kernel-gateway 2.5.2 requires jupyter-client<8.0,>=5.2.0, but you have jupyter-client 8.6.3 which is incompatible.
# jupyter-kernel-gateway 2.5.2 requires notebook<7.0,>=5.7.6, but you have notebook 7.2.2 which is incompatible.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2024.9.0 which is incompatible.
# dataproc-spark-connect 0.8.2 requires tqdm>=4.67, but you have tqdm 4.66.6 which is incompatible.
# dataproc-spark-connect 0.8.2 requires websockets>=14.0, but you have websockets 12.0 which is incompatible.
# google-genai 1.25.0 requires websockets<15.1.0,>=13.0.0, but you have websockets 12.0 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# yfinance 0.2.65 requires websockets>=13.0, but you have websockets 12.0 which is incompatible.
# umap-learn 0.5.9.post2 requires scikit-learn>=1.6, but you have scikit-learn 1.5.2 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed accelerate-1.1.0 aiofiles-23.2.1 arrow-1.3.0 async-lru-2.0.5 beautifulsoup4-4.12.3 comm-0.2.2 datasets-3.1.0 faiss-cpu-1.8.0 fqdn-1.5.1 fsspec-2024.9.0 gradio-5.5.0 gradio-client-1.4.2 ipywidgets-8.1.5 isoduration-20.11.0 jedi-0.19.2 json5-0.12.0 jupyter-1.1.1 jupyter-client-8.6.3 jupyter-events-0.12.0 jupyter-lsp-2.2.6 jupyter-server-2.16.0 jupyter-server-terminals-0.5.3 jupyterlab-4.2.7 jupyterlab-server-2.27.3 markupsafe-2.1.5 matplotlib-3.9.2 notebook-7.2.2 numpy-1.26.4 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 opencv-python-4.10.0.84 overrides-7.7.0 pandas-2.2.0 pillow-10.4.0 psutil-6.1.0 pytest-8.3.3 python-json-logger-3.3.0 python-multipart-0.0.12 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 scikit-learn-1.5.2 sentence-transformers-3.3.0 tokenizers-0.20.1 tomlkit-0.12.0 tqdm-4.66.6 transformers-4.46.0 types-python-dateutil-2.9.0.20250708 ultralytics-8.3.0 ultralytics-thop-2.0.14 uri-template-1.3.0 websockets-12.0 widgetsnbextension-4.0.14

# %%
# !pip install -r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt
# Out:
# Requirement already satisfied: numpy==1.26.4 in /usr/local/lib/python3.11/dist-packages (from -r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 5)) (1.26.4)
# Requirement already satisfied: pandas==2.2.0 in /usr/local/lib/python3.11/dist-packages (from -r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 6)) (2.2.0)
# Requirement already satisfied: torch==2.6.0 in /usr/local/lib/python3.11/dist-packages (from -r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 9)) (2.6.0+cu124)
# Requirement already satisfied: torchvision==0.21.0 in /usr/local/lib/python3.11/dist-packages (from -r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 10)) (0.21.0+cu124)
# Requirement already satisfied: torchaudio==2.6.0 in /usr/local/lib/python3.11/dist-packages (from -r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 11)) (2.6.0+cu124)
# Requirement already satisfied: tensorflow==2.18.0 in /usr/local/lib/python3.11/dist-packages (from -r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 12)) (2.18.0)
# Requirement already satisfied: transformers==4.46.0 in /usr/local/lib/python3.11/dist-packages (from -r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 15)) (4.46.0)
# Requirement already satisfied: sentence-transformers==3.3.0 in /usr/local/lib/python3.11/dist-packages (from -r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 16)) (3.3.0)
# Requirement already satisfied: datasets==3.1.0 in /usr/local/lib/python3.11/dist-packages (from -r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 17)) (3.1.0)
# Requirement already satisfied: accelerate==1.1.0 in /usr/local/lib/python3.11/dist-packages (from -r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 18)) (1.1.0)
# Requirement already satisfied: tokenizers==0.20.1 in /usr/local/lib/python3.11/dist-packages (from -r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 19)) (0.20.1)
# Requirement already satisfied: opencv-python==4.10.0.84 in /usr/local/lib/python3.11/dist-packages (from -r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 22)) (4.10.0.84)
# Requirement already satisfied: pillow==10.4.0 in /usr/local/lib/python3.11/dist-packages (from -r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 23)) (10.4.0)
# Requirement already satisfied: ultralytics==8.3.0 in /usr/local/lib/python3.11/dist-packages (from -r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 24)) (8.3.0)
# Requirement already satisfied: matplotlib==3.9.2 in /usr/local/lib/python3.11/dist-packages (from -r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 27)) (3.9.2)
# Requirement already satisfied: seaborn==0.13.2 in /usr/local/lib/python3.11/dist-packages (from -r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 28)) (0.13.2)
# Requirement already satisfied: scikit-learn==1.5.2 in /usr/local/lib/python3.11/dist-packages (from -r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 31)) (1.5.2)
# Requirement already satisfied: faiss-cpu==1.8.0 in /usr/local/lib/python3.11/dist-packages (from -r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 32)) (1.8.0)
# Requirement already satisfied: requests==2.32.3 in /usr/local/lib/python3.11/dist-packages (from -r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 35)) (2.32.3)
# Requirement already satisfied: beautifulsoup4==4.12.3 in /usr/local/lib/python3.11/dist-packages (from -r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 36)) (4.12.3)
# Requirement already satisfied: gradio==5.5.0 in /usr/local/lib/python3.11/dist-packages (from -r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 37)) (5.5.0)
# Requirement already satisfied: jupyter==1.1.1 in /usr/local/lib/python3.11/dist-packages (from -r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 40)) (1.1.1)
# Requirement already satisfied: ipywidgets==8.1.5 in /usr/local/lib/python3.11/dist-packages (from -r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 41)) (8.1.5)
# Requirement already satisfied: notebook==7.2.2 in /usr/local/lib/python3.11/dist-packages (from -r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (7.2.2)
# Requirement already satisfied: tqdm==4.66.6 in /usr/local/lib/python3.11/dist-packages (from -r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 45)) (4.66.6)
# Requirement already satisfied: psutil==6.1.0 in /usr/local/lib/python3.11/dist-packages (from -r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 46)) (6.1.0)
# Requirement already satisfied: pytest==8.3.3 in /usr/local/lib/python3.11/dist-packages (from -r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 49)) (8.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas==2.2.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 6)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas==2.2.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 6)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas==2.2.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 6)) (2025.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 9)) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 9)) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 9)) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 9)) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 9)) (2024.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 9)) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 9)) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 9)) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 9)) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 9)) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 9)) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 9)) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 9)) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 9)) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 9)) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 9)) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 9)) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 9)) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 9)) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 9)) (1.13.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 12)) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 12)) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 12)) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 12)) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 12)) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 12)) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 12)) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 12)) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 12)) (5.29.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 12)) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 12)) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 12)) (3.1.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 12)) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 12)) (1.73.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 12)) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 12)) (3.8.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 12)) (3.14.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 12)) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 12)) (0.37.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.11/dist-packages (from transformers==4.46.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 15)) (0.33.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.46.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 15)) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.46.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 15)) (2024.11.6)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.46.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 15)) (0.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from sentence-transformers==3.3.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 16)) (1.15.3)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets==3.1.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 17)) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets==3.1.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 17)) (0.3.7)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets==3.1.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 17)) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets==3.1.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 17)) (0.70.15)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets==3.1.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 17)) (3.11.15)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics==8.3.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 24)) (9.0.0)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics==8.3.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 24)) (2.0.14)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.9.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 27)) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.9.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 27)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.9.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 27)) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.9.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 27)) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.9.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 27)) (3.2.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.5.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 31)) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.5.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 31)) (3.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests==2.32.3->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 35)) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests==2.32.3->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 35)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests==2.32.3->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 35)) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests==2.32.3->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 35)) (2025.7.14)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4==4.12.3->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 36)) (2.7)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /usr/local/lib/python3.11/dist-packages (from gradio==5.5.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 37)) (23.2.1)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.11/dist-packages (from gradio==5.5.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 37)) (4.9.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /usr/local/lib/python3.11/dist-packages (from gradio==5.5.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 37)) (0.116.1)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.11/dist-packages (from gradio==5.5.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 37)) (0.6.0)
# Requirement already satisfied: gradio-client==1.4.2 in /usr/local/lib/python3.11/dist-packages (from gradio==5.5.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 37)) (1.4.2)
# Requirement already satisfied: httpx>=0.24.1 in /usr/local/lib/python3.11/dist-packages (from gradio==5.5.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 37)) (0.28.1)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.11/dist-packages (from gradio==5.5.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 37)) (2.1.5)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.11/dist-packages (from gradio==5.5.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 37)) (3.11.0)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.11/dist-packages (from gradio==5.5.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 37)) (2.11.7)
# Requirement already satisfied: pydub in /usr/local/lib/python3.11/dist-packages (from gradio==5.5.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 37)) (0.25.1)
# Requirement already satisfied: python-multipart==0.0.12 in /usr/local/lib/python3.11/dist-packages (from gradio==5.5.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 37)) (0.0.12)
# Requirement already satisfied: ruff>=0.2.2 in /usr/local/lib/python3.11/dist-packages (from gradio==5.5.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 37)) (0.12.3)
# Requirement already satisfied: safehttpx<1.0,>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from gradio==5.5.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 37)) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.11/dist-packages (from gradio==5.5.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 37)) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /usr/local/lib/python3.11/dist-packages (from gradio==5.5.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 37)) (0.47.1)
# Requirement already satisfied: tomlkit==0.12.0 in /usr/local/lib/python3.11/dist-packages (from gradio==5.5.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 37)) (0.12.0)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.11/dist-packages (from gradio==5.5.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 37)) (0.16.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.11/dist-packages (from gradio==5.5.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 37)) (0.35.0)
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.11/dist-packages (from jupyter==1.1.1->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 40)) (6.1.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.11/dist-packages (from jupyter==1.1.1->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 40)) (7.16.6)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.11/dist-packages (from jupyter==1.1.1->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 40)) (6.17.1)
# Requirement already satisfied: jupyterlab in /usr/local/lib/python3.11/dist-packages (from jupyter==1.1.1->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 40)) (4.2.7)
# Requirement already satisfied: comm>=0.1.3 in /usr/local/lib/python3.11/dist-packages (from ipywidgets==8.1.5->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 41)) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets==8.1.5->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 41)) (7.34.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.11/dist-packages (from ipywidgets==8.1.5->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 41)) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /usr/local/lib/python3.11/dist-packages (from ipywidgets==8.1.5->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 41)) (4.0.14)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /usr/local/lib/python3.11/dist-packages (from ipywidgets==8.1.5->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 41)) (3.0.15)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (2.16.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /usr/local/lib/python3.11/dist-packages (from notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (2.27.3)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /usr/local/lib/python3.11/dist-packages (from notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (6.4.2)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.11/dist-packages (from pytest==8.3.3->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 49)) (2.1.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.11/dist-packages (from pytest==8.3.3->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 49)) (1.6.0)
# Requirement already satisfied: websockets<13.0,>=10.0 in /usr/local/lib/python3.11/dist-packages (from gradio-client==1.4.2->gradio==5.5.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 37)) (12.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch==2.6.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 9)) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<5.0,>=3.0->gradio==5.5.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 37)) (1.3.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow==2.18.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 12)) (0.45.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets==3.1.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 17)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets==3.1.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 17)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets==3.1.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 17)) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets==3.1.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 17)) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets==3.1.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 17)) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets==3.1.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 17)) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets==3.1.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 17)) (1.20.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.24.1->gradio==5.5.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 37)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.24.1->gradio==5.5.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 37)) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.46.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 15)) (1.1.5)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.11/dist-packages (from ipython>=6.1.0->ipywidgets==8.1.5->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 41)) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=6.1.0->ipywidgets==8.1.5->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 41)) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=6.1.0->ipywidgets==8.1.5->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 41)) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=6.1.0->ipywidgets==8.1.5->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 41)) (3.0.51)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython>=6.1.0->ipywidgets==8.1.5->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 41)) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=6.1.0->ipywidgets==8.1.5->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 41)) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from ipython>=6.1.0->ipywidgets==8.1.5->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 41)) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=6.1.0->ipywidgets==8.1.5->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 41)) (4.9.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=2.4.0->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (25.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=2.4.0->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=2.4.0->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (5.8.1)
# Requirement already satisfied: jupyter-events>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=2.4.0->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=2.4.0->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (0.5.3)
# Requirement already satisfied: nbformat>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=2.4.0->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=2.4.0->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=2.4.0->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (0.22.1)
# Requirement already satisfied: pyzmq>=24 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=2.4.0->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (24.0.1)
# Requirement already satisfied: send2trash>=1.8.2 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=2.4.0->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=2.4.0->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=2.4.0->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from jupyterlab->jupyter==1.1.1->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 40)) (2.0.5)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from jupyterlab->jupyter==1.1.1->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 40)) (2.2.6)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel->jupyter==1.1.1->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 40)) (1.8.0)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from ipykernel->jupyter==1.1.1->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 40)) (1.6.0)
# Requirement already satisfied: babel>=2.10 in /usr/local/lib/python3.11/dist-packages (from jupyterlab-server<3,>=2.27.1->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from jupyterlab-server<3,>=2.27.1->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (0.12.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /usr/local/lib/python3.11/dist-packages (from jupyterlab-server<3,>=2.27.1->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (4.24.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow==2.18.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 12)) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow==2.18.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 12)) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow==2.18.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 12)) (0.16.0)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert->jupyter==1.1.1->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 40)) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/dist-packages (from nbconvert->jupyter==1.1.1->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 40)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.11/dist-packages (from nbconvert->jupyter==1.1.1->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 40)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from nbconvert->jupyter==1.1.1->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 40)) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert->jupyter==1.1.1->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 40)) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from nbconvert->jupyter==1.1.1->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 40)) (1.5.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.0->gradio==5.5.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 37)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.0->gradio==5.5.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 37)) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.0->gradio==5.5.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 37)) (0.4.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow==2.18.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 12)) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow==2.18.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 12)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow==2.18.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 12)) (3.1.3)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0,>=0.12->gradio==5.5.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 37)) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0,>=0.12->gradio==5.5.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 37)) (1.5.4)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.11/dist-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (21.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter==1.1.1->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 40)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert->jupyter==1.1.1->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 40)) (1.4.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets==8.1.5->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 41)) (0.8.4)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (0.26.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (4.3.8)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.11/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (3.3.0)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.11/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (0.1.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.11/dist-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (2.21.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets==8.1.5->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 41)) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=6.1.0->ipywidgets==8.1.5->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 41)) (0.2.13)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow==2.18.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 12)) (3.0.0)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.11/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.11/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.11/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (3.0.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.11/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (24.11.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow==2.18.0->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 12)) (0.1.2)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.11/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /usr/local/lib/python3.11/dist-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook==7.2.2->-r https://raw.githubusercontent.com/insanesac/ai_workshop/main/requirements.txt (line 42)) (2.9.0.20250708)

# %%
# TODO: Import the sys module
import sys

# TODO: Print the Python version using sys.version
print(f"Python version: {sys.version}")

# TODO: Print the Python executable path using sys.executable
print(f"Python executable: {sys.executable}")

# TODO: Check if Python version is 3.10 or higher
version_info = sys.version_info
if version_info.major == 3 and version_info.minor >= 10:
    print("✅ Python version is compatible!")
else:
    print("❌ Python version is too old. Please upgrade to 3.10+")
# Out:
# Python version: 3.11.13 (main, Jun  4 2025, 08:57:29) [GCC 11.4.0]
# Python executable: /usr/bin/python3
# ✅ Python version is compatible!

# %%
# TODO: Try importing all required packages and handle any ImportError
required_packages = {
    'torch': 'PyTorch deep learning framework',
    'transformers': 'Hugging Face transformers library',
    'cv2': 'OpenCV computer vision library',
    'numpy': 'Numerical computing library',
    'pandas': 'Data manipulation library',
    'matplotlib': 'Plotting library',
    'gradio': 'Web UI library for ML demos'
}

import_results = []

for package_name, description in required_packages.items():
    try:
        # TODO: Use __import__() or importlib to import the package
        ___  # Your import code here

        print(f"✅ {package_name} - {description}")
        import_results.append((package_name, True))
    except ImportError as e:
        # TODO: Handle the import error and print a helpful message
        print(f"❌ {package_name} - Missing! {description}")
        import_results.append((package_name, False))

# TODO: Print summary of results
failed_imports = [pkg for pkg, success in import_results if not success]
if failed_imports:
    print(f"\n⚠️ Install missing packages: pip install {' '.join(failed_imports)}")
else:
    print("\n🎉 All packages imported successfully!")
# Out:
# ✅ torch - PyTorch deep learning framework
# ✅ transformers - Hugging Face transformers library
# ✅ cv2 - OpenCV computer vision library
# ✅ numpy - Numerical computing library
# ✅ pandas - Data manipulation library
# ✅ matplotlib - Plotting library
# ✅ gradio - Web UI library for ML demos
#
# 🎉 All packages imported successfully!

# %%
import torch

# TODO: Check if CUDA is available
cuda_available = torch.cuda.is_available()  # Use torch.cuda method

print(f"CUDA available: {cuda_available}")

if cuda_available:
    # TODO: Get GPU device name
    gpu_name = torch.cuda.get_device_name(0)  # Use torch.cuda method
    print(f"GPU device: {gpu_name}")

    # TODO: Get CUDA version
    cuda_version = torch.version.cuda  # Use torch.version attribute
    print(f"CUDA version: {cuda_version}")

    # TODO: Get number of available GPUs
    gpu_count = torch.cuda.device_count()  # Use torch.cuda method
    print(f"Number of GPUs: {gpu_count}")

else:
    print("⚠️ No GPU available - using CPU")
    print("💡 Consider using Google Colab for free GPU access")

# TODO: Set device for computations
device = torch.device("cuda") if cuda_available else torch.device("cpu")  # torch.device
print(f"\nUsing device: {device}")
# Out:
# CUDA available: True
# GPU device: Tesla T4
# CUDA version: 12.4
# Number of GPUs: 1
#
# Using device: cuda

# %%
import time
import psutil  # You may need to install this: pip install psutil

# System RAM check
ram_info = psutil.virtual_memory()
print(f"Total RAM: {ram_info.total / (1024**3):.1f} GB")
print(f"Available RAM: {ram_info.available / (1024**3):.1f} GB")

# GPU memory check (if available)
if cuda_available:
    # TODO: Get GPU memory info using torch.cuda methods
    total_memory = torch.cuda.get_device_properties(0).total_memory  # total GPU memory
    allocated_memory = torch.cuda.memory_allocated(0)  # allocated GPU memory

    print(f"\nGPU Total Memory: {total_memory / (1024**3):.1f} GB")
    print(f"GPU Allocated Memory: {allocated_memory / (1024**3):.1f} GB")

# Simple performance test
print("\n🔬 Running performance test...")

# TODO: Create two large random tensors
size = 1000
a = torch.randn(size, size)  # Create on CPU first
b = torch.randn(size, size)

# CPU timing
start_time = time.time()
# TODO: Perform matrix multiplication on CPU
result_cpu = torch.matmul(a, b)  # or result_cpu = a @ b
cpu_time = time.time() - start_time

print(f"CPU computation time: {cpu_time:.4f} seconds")

# GPU timing (if available)
if cuda_available:
    # TODO: Move tensors to GPU
    a_gpu = a.to(device)  # move tensor to GPU
    b_gpu = b.to(device)

    # TODO: Warm up GPU (run operation once)
    _ = torch.matmul(a_gpu, b_gpu)
    torch.cuda.synchronize()  # Wait for GPU to finish

    start_time = time.time()
    # TODO: Perform matrix multiplication on GPU
    result_gpu = torch.matmul(a_gpu, b_gpu)
    torch.cuda.synchronize()
    gpu_time = time.time() - start_time

    print(f"GPU computation time: {gpu_time:.4f} seconds")
    print(f"Speedup: {cpu_time/gpu_time:.1f}x faster on GPU")

print("✅ Performance test complete!")
# Out:
# Total RAM: 12.7 GB
# Available RAM: 11.3 GB
#
# GPU Total Memory: 14.7 GB
# GPU Allocated Memory: 0.0 GB
#
# 🔬 Running performance test...
# CPU computation time: 0.0953 seconds
# GPU computation time: 0.0011 seconds
# Speedup: 85.8x faster on GPU
# ✅ Performance test complete!

# %%
import torch

print("=== Tensor Creation ===")

# TODO: Create different types of tensors
# 1. From a Python list
list_tensor = torch.tensor([1,2,3,4,5])  # torch.tensor([1, 2, 3, 4, 5])

# 2. Zeros tensor of shape (3, 4)
zeros_tensor = torch.zeros(3,4)  # torch.zeros(...)

# 3. Random tensor of shape (2, 3, 4)
random_tensor = torch.randn(2,3,4)  # torch.randn(...)

# 4. Tensor of ones with same shape as random_tensor
ones_like = torch.ones_like(random_tensor)  # torch.ones_like(...)

print(f"List tensor: {list_tensor}")
print(f"Zeros shape: {zeros_tensor.shape}")
print(f"Random shape: {random_tensor.shape}")
print(f"Ones like shape: {ones_like.shape}")

print("\n=== Tensor Properties ===")
# TODO: Print tensor properties
x = torch.randn(3, 4, 5)
print(f"Shape: {x.shape}")  # x.shape or x.size()
print(f"Data type: {x.dtype}")  # x.dtype
print(f"Device: {x.device}")  # x.device
print(f"Number of elements: {x.numel()}")  # x.numel()
print(f"Number of dimensions: {x.ndim}")  # x.ndim or len(x.shape)
# Out:
# === Tensor Creation ===
# List tensor: tensor([1, 2, 3, 4, 5])
# Zeros shape: torch.Size([3, 4])
# Random shape: torch.Size([2, 3, 4])
# Ones like shape: torch.Size([2, 3, 4])
#
# === Tensor Properties ===
# Shape: torch.Size([3, 4, 5])
# Data type: torch.float32
# Device: cpu
# Number of elements: 60
# Number of dimensions: 3

# %%
print("=== Tensor Operations ===")

# Create sample tensors
a = torch.tensor([[1, 2], [3, 4]], dtype=torch.float32)
b = torch.tensor([[5, 6], [7, 8]], dtype=torch.float32)

print(f"Tensor a:\n{a}")
print(f"Tensor b:\n{b}")

# TODO: Perform basic operations
# 1. Element-wise addition
addition = a + b  # or torch.add(a, b)

# 2. Element-wise multiplication
element_mult = a * b  # element-wise multiplication

# 3. Matrix multiplication
matrix_mult = torch.matmul(a, b)  # or a @ b

# 4. Transpose of tensor a
transpose = a.T  # or torch.transpose(a, 0, 1)

print(f"\nAddition:\n{addition}")
print(f"Element-wise multiplication:\n{element_mult}")
print(f"Matrix multiplication:\n{matrix_mult}")
print(f"Transpose of a:\n{transpose}")

# TODO:
# Out:
# === Tensor Operations ===
# Tensor a:
# tensor([[1., 2.],
#         [3., 4.]])
# Tensor b:
# tensor([[5., 6.],
#         [7., 8.]])
#
# Addition:
# tensor([[ 6.,  8.],
#         [10., 12.]])
# Element-wise multiplication:
# tensor([[ 5., 12.],
#         [21., 32.]])
# Matrix multiplication:
# tensor([[19., 22.],
#         [43., 50.]])
# Transpose of a:
# tensor([[1., 3.],
#         [2., 4.]])

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn

# Set random seed for reproducibility
np.random.seed(42)
torch.manual_seed(42)

# %%
# Generate synthetic dataset
# TODO: Fill in the parameters for make_classification
# Hint: We want 1000 samples, 2 features, 2 classes, and some noise
X, y = make_classification(
    n_samples=1000,     # Number of samples
    n_features=2,       # Number of features
    n_classes=2,        # Number of classes
    n_redundant=0,      # No redundant features
    n_informative=2,    # Both features are informative
    n_clusters_per_class=1,  # Simpler decision boundary
    flip_y=0.05,        # Add 5% label noise
    class_sep=1.0,      # Class separation (optional tuning)
    random_state=42
)

print(f"Dataset shape: {X.shape}")
print(f"Labels shape: {y.shape}")
print(f"Unique labels: {np.unique(y)}")
# Out:
# Dataset shape: (1000, 2)
# Labels shape: (1000,)
# Unique labels: [0 1]

# %%
# Visualize the data
plt.figure(figsize=(10, 6))

# TODO: Create a scatter plot of the data
# Hint: Use different colors for different classes
# Use plt.scatter(X[:, 0], X[:, 1], c=y, cmap='viridis')
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='viridis', edgecolor='k')

plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Synthetic Binary Classification Dataset')
plt.colorbar(label='Class')
plt.grid(True, alpha=0.3)
plt.show()

# TODO: Calculate and print basic statistics
print(f"Class distribution: {np.bincount(y)}")  # Hint: Use np.bincount(y)
print(f"Feature 1 range: [{X[:, 0].min():.2f}, {X[:, 0].max():.2f}]")  # Hint: Use X[:, 0].min() and max()
print(f"Feature 2 range: [{X[:, 1].min():.2f}, {X[:, 1].max():.2f}]")  # Hint: Use X[:, 1].min() and max()
# Out:
# Class distribution: [502 498]
# Feature 1 range: [-2.85, 3.34]
# Feature 2 range: [-2.47, 4.14]

# %%
# TODO: Split the data into training and testing sets
# Hint: Use train_test_split with test_size=0.2
X_train, X_test, y_train, y_test = train_test_split(
    X,         # Features
    y,         # Labels
    test_size=0.2,  # 20% data for testing
    random_state=42,
    stratify=y       # Maintain class balance in splits
)

print(f"Training set shape: {X_train.shape}")
print(f"Testing set shape: {X_test.shape}")
print(f"Training labels distribution: {np.bincount(y_train)}")  # Use np.bincount
print(f"Testing labels distribution: {np.bincount(y_test)}")    # Use np.bincount
# Out:
# Training set shape: (800, 2)
# Testing set shape: (200, 2)
# Training labels distribution: [402 398]
# Testing labels distribution: [100 100]

# %%
class SimpleNeuralNetwork:
    def __init__(self, input_size, hidden_size, output_size):
        """
        Initialize a simple 2-layer neural network

        Args:
            input_size: Number of input features
            hidden_size: Number of neurons in hidden layer
            output_size: Number of output neurons
        """
        # Weights from input to hidden layer
        self.W1 = np.random.randn(input_size, hidden_size) * 0.01  # Shape: (input_size, hidden_size)
        self.b1 = np.zeros((1, hidden_size))                        # Shape: (1, hidden_size)

        # Weights from hidden to output layer
        self.W2 = np.random.randn(hidden_size, output_size) * 0.01  # Shape: (hidden_size, output_size)
        self.b2 = np.zeros((1, output_size))                        # Shape: (1, output_size)

    def sigmoid(self, x):
        """
        Sigmoid activation function: 1 / (1 + exp(-x))
        """
        x = np.clip(x, -500, 500)  # Prevent overflow
        return 1 / (1 + np.exp(-x))

    def sigmoid_derivative(self, x):
        """
        Derivative of sigmoid activation
        """
        sig = self.sigmoid(x)
        return sig * (1 - sig)

    def forward(self, X):
        """
        Forward propagation:
        X → Hidden Layer (sigmoid) → Output Layer (sigmoid)
        """
        # Input to hidden layer
        self.z1 = X @ self.W1 + self.b1  # Linear combination
        self.a1 = self.sigmoid(self.z1)  # Activation

        # Hidden to output layer
        self.z2 = self.a1 @ self.W2 + self.b2  # Linear combination
        self.a2 = self.sigmoid(self.z2)        # Final output (probabilities)

        return self.a2

    def compute_loss(self, y_true, y_pred):
        """
        Binary Cross-Entropy Loss:
        -[y*log(y_pred) + (1-y)*log(1-y_pred)]
        """
        epsilon = 1e-15
        y_pred = np.clip(y_pred, epsilon, 1 - epsilon)

        loss = - (y_true * np.log(y_pred) + (1 - y_true) * np.log(1 - y_pred))
        return np.mean(loss)

# Test the network initialization
network = SimpleNeuralNetwork(input_size=2, hidden_size=4, output_size=1)
print(f"W1 shape: {network.W1.shape}")
print(f"W2 shape: {network.W2.shape}")
print("Network initialized successfully!")
# Out:
# W1 shape: (2, 4)
# W2 shape: (4, 1)
# Network initialized successfully!
